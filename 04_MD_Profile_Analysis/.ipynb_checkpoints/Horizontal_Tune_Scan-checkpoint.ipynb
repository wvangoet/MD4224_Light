# %% [markdown]
# # MD4424 Horizontal Tune Scan
# - MD data already analysed on SWAN, loaded here as a pandas dataframe saved via pickle
# - Here we load the simulated bunch distributions and analyse them in the same way as the MD data to compare

# %% [markdown]
# ###  Load functions and imports etc

# %%
# %run ./MD_Functions.ipynb
# Out:
# 	Importing MD Analysis functions for MD4224

# %% [markdown]
# ### Make a directory for output plots

# %%
path = './H_Plots'
make_directory(path)
path = './H_Plots/MD'
make_directory(path)
path = './H_Plots/WS_tomo'
make_directory(path)
path = './H_Plots/WS_BLonD'
make_directory(path)
path = './H_Sim_Dataframes'
make_directory(path)
# Out:
# Creation of the directory ./H_Plots failed
# Creation of the directory ./H_Plots/MD failed
# Creation of the directory ./H_Plots/WS_tomo failed
# Creation of the directory ./H_Plots/WS_BLonD failed
# Successfully created the directory ./H_Sim_Dataframes

# %% [markdown]
# ###  Load and check MD dataframe

# %%
df0 = pnd.read_pickle('MD_Dataframes/MD4224_HighBrightness_Horizontal_Using_Sim_Optics_Complete.pkl')

# %%
df0
# Out:
#                          PR.BWS.65.H_ROT:ACQ_DELAY  \
# 2018-09-04 08:30:23.500                      172.0
# 2018-09-04 08:31:07.900                      172.0
# 2018-09-04 08:31:52.300                      172.0
# 2018-09-04 08:33:21.100                      172.0
# 2018-09-04 08:34:49.900                      172.0
# 2018-09-04 08:36:18.700                      172.0
# 2018-09-04 08:37:47.500                      172.0
# 2018-09-04 08:39:16.300                      172.0
# 2018-09-04 08:40:45.100                      172.0
# 2018-09-04 08:42:13.900                      175.0
# 2018-09-04 08:43:42.700                      175.0
# 2018-09-04 08:45:11.500                      175.0
# 2018-09-04 08:46:40.300                      175.0
# 2018-09-04 08:48:09.100                      175.0
# 2018-09-04 08:51:06.700                      175.0
# 2018-09-04 08:52:35.500                      175.0
# 2018-09-04 08:54:04.300                      185.0
# 2018-09-04 08:55:33.100                      185.0
# 2018-09-04 08:57:01.900                      185.0
# 2018-09-04 08:58:30.700                      185.0
# 2018-09-04 08:59:59.500                      185.0
# 2018-09-04 09:01:28.300                      185.0
# 2018-09-04 09:02:57.100                      185.0
# 2018-09-04 09:04:25.900                      185.0
# 2018-09-04 09:05:54.700                      172.0
# 2018-09-04 09:07:23.500                      172.0
# 2018-09-04 09:08:52.300                      172.0
# 2018-09-04 09:10:21.100                      172.0
# 2018-09-04 09:11:49.900                      172.0
# 2018-09-04 09:13:18.700                      172.0
# ...                                            ...
# 2018-09-04 13:47:06.700                      185.0
# 2018-09-04 13:48:35.500                      185.0
# 2018-09-04 13:50:04.300                      185.0
# 2018-09-04 13:51:33.100                      185.0
# 2018-09-04 13:53:01.900                      185.0
# 2018-09-04 13:54:30.700                      185.0
# 2018-09-04 13:55:59.500                      185.0
# 2018-09-04 13:57:28.300                      185.0
# 2018-09-04 13:58:57.100                      172.0
# 2018-09-04 14:01:54.700                      172.0
# 2018-09-04 14:03:23.500                      172.0
# 2018-09-04 14:04:52.300                      172.0
# 2018-09-04 14:06:21.100                      172.0
# 2018-09-04 14:07:49.900                      172.0
# 2018-09-04 14:18:11.500                      2.584263               1.458795
# 2018-09-04 14:19:40.300                      3.008447               1.786515
# 2018-09-04 14:21:09.100                      4.948582               3.597415
# 2018-09-04 14:22:37.900                      2.119435               1.219002
# 2018-09-04 14:24:06.700                      1.965669               1.036968
# 2018-09-04 14:25:35.500                      2.148532               1.185599
# 2018-09-04 14:27:04.300                      2.169699               1.165212
# 2018-09-04 14:28:33.100                      2.391986               1.335846
# 2018-09-04 14:30:01.900                      2.629242               1.504171
# 2018-09-04 14:31:30.700                      3.313203               2.091032
#
# [225 rows x 24 columns]

# %% [markdown]
# ### Create a dictionary to organise shots by distinct working point

# %%
# These are our tune points:
scan_points = np.linspace(607, 621, 15);
scan_points = scan_points/100;
print '\nscan_points = ', scan_points

Qx_points=[]
for i in scan_points:
    Qx_points.append(round_sig(i,5))
print '\nQx_points = ', Qx_points

Qx_point_separation = Qx_points[1] - Qx_points[0]
Qx_pt_sep = Qx_point_separation/2
print '\nTune points separated by +/- ', Qx_pt_sep

# Make dictionary of nearest tune point and iterators
tune_points = {}
for i in Qx_points:
    tune_points[i] = np.where(np.logical_and(np.greater_equal(df0['Qx'], (i-Qx_pt_sep-6)), np.less_equal(df0['Qx'], (i+Qx_pt_sep-6)) ) )[0]
print '\ntune_points dictionary:\n'
tune_points
# Out:
# scan_points =  [6.07 6.08 6.09 6.1  6.11 6.12 6.13 6.14 6.15 6.16 6.17 6.18 6.19 6.2
#  6.21]
#
# Qx_points =  [6.07, 6.08, 6.09, 6.1, 6.11, 6.12, 6.13, 6.14, 6.15, 6.16, 6.17, 6.18, 6.19, 6.2, 6.21]
#
# Tune points separated by +/-  0.005
#
# tune_points dictionary:
# {6.07: array([187, 202, 209, 217]),
#  6.08: array([  8,  15,  23,  31,  39,  46,  54,  62,  76,  84,  91,  99, 107,
#         114, 128, 136, 142, 148, 155, 163, 171, 179]),
#  6.09: array([186, 194, 201, 208, 216, 224]),
#  6.1: array([  7,  14,  22,  30,  38,  45,  53,  61,  69,  75,  83,  90,  98,
#         106, 113, 121, 127, 135, 141, 154, 162, 170, 178]),
#  6.11: array([  6,  21,  29,  37,  52,  60,  68,  82,  89,  97, 105, 112, 120,
#         134, 140, 153, 161, 169, 177, 185, 193, 200, 207, 215, 223]),
#  6.12: array([ 44, 184, 192, 199, 206, 214, 222]),
#  6.13: array([  5,  13,  20,  28,  36,  43,  51,  59,  67,  74,  81,  96, 104,
#         111, 119, 126, 133, 147, 160, 168, 176]),
#  6.14: array([183, 191, 198, 205, 213, 221]),
#  6.15: array([  4,  12,  19,  27,  35,  50,  58,  66,  73,  80,  88,  95, 103,
#         110, 118, 125, 132, 146, 152, 159, 167, 175]),
#  6.16: array([182, 190, 197, 204, 212, 220]),
#  6.17: array([  3,  11,  18,  26,  34,  42,  49,  57,  65,  72,  79,  87,  94,
#         102, 109, 117, 124, 131, 139, 145, 151, 158, 166, 174, 181]),
#  6.18: array([180, 189, 196, 211, 219]),
#  6.19: array([  2,  10,  17,  25,  33,  41,  48,  56,  64,  71,  78,  86,  93,
#         101, 108, 116, 123, 130, 138, 144, 150, 157, 165, 173]),
#  6.2: array([  1, 188, 195, 203, 210, 218]),
#  6.21: array([  0,   9,  16,  24,  32,  40,  47,  55,  63,  70,  77,  85,  92,
#         100, 115, 122, 129, 137, 143, 149, 156, 164, 172])}

# %%
x_ticks = [6.06, 6.08, 6.10, 6.12, 6.14, 6.16,  6.18, 6.20 , 6.22]

# %%
fig=plt.figure(figsize=(6, 4), dpi= 200, facecolor='w', edgecolor='k');
plt.plot(df0['Qx'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)]+6, df0['2ndMoment H'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)]/df0['sig H'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)],'bo', label='Measurement @ 172 ms');
plt.plot(df0['Qx'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==175)]+6, df0['2ndMoment H'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==175)]/df0['sig H'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==175)],'ro', label='Measurement @ 175 ms');
plt.plot(df0['Qx'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==185)]+6, df0['2ndMoment H'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==185)]/df0['sig H'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==185)],'co', label='Measurement @ 185 ms');
plt.xlabel('Qx');
plt.ylabel(r'$\frac{\sigma_{x_{Second Moment}}}{\sigma_{x_{Standard Deviation}}}$ [-]');
plt.legend(loc=4);
#plt.title('Wire Scanner Acquisition Delay');
#plt.xlim(6.075, 6.25);
plt.ylim(0.8, 1.2);
plt.xlim(6.06, 6.22)
plt.xticks(x_ticks)
plt.grid();
fig.savefig('./H_Plots/MD/Gaussianness.png');

# %%
# Plot averaged data points with error bars
fig=plt.figure(figsize=(6, 4), dpi= 200, facecolor='w', edgecolor='k');
x_data = np.linspace(607, 621, 15);
x_data = x_data/100;

y_data_172 = []
y_data_175 = []
y_data_185 = []

y_error_172 = []
y_error_175 = []
y_error_185 = []

for i in x_data:
    
    upper_lim = i+0.0049999999999 - 6
    lower_lim = i-0.0049999999999 - 6
    
    y_data_172.append( np.mean( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    y_data_175.append( np.mean( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==175)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    y_data_185.append( np.mean( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==185)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    
    y_error_172.append( np.std( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    y_error_175.append( np.std( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==175)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    y_error_185.append( np.std( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==185)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    
    
plt.errorbar(x_data, y_data_172, y_error_172, label='Measurement @ 172 ms', linestyle='None', marker='o', capsize=3, color='b')
plt.errorbar(x_data, y_data_175, y_error_175, label='Measurement @ 175 ms', linestyle='None', marker='o', capsize=3, color='r')
plt.errorbar(x_data, y_data_185, y_error_185, label='Measurement @ 185 ms', linestyle='None', marker='o', capsize=3, color='c')

plt.xlabel('Qx');
plt.ylabel('Horizontal Emittance [mm mrad]');

#plt.title(r'$\epsilon_{x} = \beta\gamma \frac{\mu\prime_x^2 - D_x^2 \left(\frac{\delta p}{p}\right)^2}{\beta_{x}(s)}$')

plt.ylim(0.5, 4)
plt.xticks(x_ticks)

plt.legend();
plt.grid();
fig.savefig('H_Plots/MD/H_Emitt_MD_all.png');

# %%
# Plot averaged data points with error bars
fig=plt.figure(figsize=(6, 4), dpi= 200, facecolor='w', edgecolor='k');
x_data = np.linspace(607, 621, 15);
x_data = x_data/100;

y_data_172 = []
y_error_172 = []

for i in x_data:
    
    upper_lim = i+0.0049999999999 - 6
    lower_lim = i-0.0049999999999 - 6
    
    y_data_172.append( np.mean( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    y_error_172.append( np.std( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
        
plt.errorbar(x_data, y_data_172, y_error_172, label='Measurement @ 172 ms', linestyle='None', marker='o', capsize=3, color='b')

plt.xlabel('Qx');
plt.ylabel('Horizontal Emittance [mm mrad]');
#plt.title(r'$\epsilon_{x} = \beta\gamma \frac{\sigma_x^2 - D_x^2 \left(\frac{\delta p}{p}^2 \right)}{\beta_{x}(s)}$')
#plt.title(r'$\epsilon_{x,y} = \beta\gamma \frac{\sigma^2}{\beta_{x,y}(s)}$')

plt.ylim(0.5, 4)
plt.xticks(x_ticks)

plt.legend();
plt.grid();
fig.savefig('./H_Plots/MD/H_Emitt_MD_172.png');

# %% [markdown]
# # Load distributions from simulations data

# %%
# Read .mat files into a dictionary

tomo_sims = '02_Mini_Simulation_Scan'

tomo_matfiles = [
    str('../'+str(tomo_sims)+'/1_H_07/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_08/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_09/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_10/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_11/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_12/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_13/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_14/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_15/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_16/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_17/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_18/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_19/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_20/bunch_output/mainbunch_000874.mat'),
    str('../'+str(tomo_sims)+'/1_H_21/bunch_output/mainbunch_000874.mat')    
]

BLonD_sims = '03_Mini_Simulation_Scan_BLonD'

BLonD_matfiles = [
    str('../'+str(BLonD_sims)+'/1_H_07/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_08/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_09/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_10/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_11/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_12/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_13/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_14/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_15/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_16/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_17/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_18/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_19/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_20/bunch_output/mainbunch_000874.mat'),
    str('../'+str(BLonD_sims)+'/1_H_21/bunch_output/mainbunch_000874.mat')    
]

sims_tomo = dict()
sims_BLonD = dict()

for f in tomo_matfiles:    
    str_tune = f.split('/')[2].split('_')[-1]
    sims_tomo[str(str_tune)] = f
    
for f in BLonD_matfiles:    
    str_tune = f.split('/')[2].split('_')[-1]
    sims_BLonD[str(str_tune)] = f

# %%
sims_tomo
# Out:
# {'07': '../02_Mini_Simulation_Scan/1_H_07/bunch_output/mainbunch_000874.mat',
#  '08': '../02_Mini_Simulation_Scan/1_H_08/bunch_output/mainbunch_000874.mat',
#  '09': '../02_Mini_Simulation_Scan/1_H_09/bunch_output/mainbunch_000874.mat',
#  '10': '../02_Mini_Simulation_Scan/1_H_10/bunch_output/mainbunch_000874.mat',
#  '11': '../02_Mini_Simulation_Scan/1_H_11/bunch_output/mainbunch_000874.mat',
#  '12': '../02_Mini_Simulation_Scan/1_H_12/bunch_output/mainbunch_000874.mat',
#  '13': '../02_Mini_Simulation_Scan/1_H_13/bunch_output/mainbunch_000874.mat',
#  '14': '../02_Mini_Simulation_Scan/1_H_14/bunch_output/mainbunch_000874.mat',
#  '15': '../02_Mini_Simulation_Scan/1_H_15/bunch_output/mainbunch_000874.mat',
#  '16': '../02_Mini_Simulation_Scan/1_H_16/bunch_output/mainbunch_000874.mat',
#  '17': '../02_Mini_Simulation_Scan/1_H_17/bunch_output/mainbunch_000874.mat',
#  '18': '../02_Mini_Simulation_Scan/1_H_18/bunch_output/mainbunch_000874.mat',
#  '19': '../02_Mini_Simulation_Scan/1_H_19/bunch_output/mainbunch_000874.mat',
#  '20': '../02_Mini_Simulation_Scan/1_H_20/bunch_output/mainbunch_000874.mat',
#  '21': '../02_Mini_Simulation_Scan/1_H_21/bunch_output/mainbunch_000874.mat'}

# %%
sims_BLonD
# Out:
# {'07': '../03_Mini_Simulation_Scan_BLonD/1_H_07/bunch_output/mainbunch_000874.mat',
#  '08': '../03_Mini_Simulation_Scan_BLonD/1_H_08/bunch_output/mainbunch_000874.mat',
#  '09': '../03_Mini_Simulation_Scan_BLonD/1_H_09/bunch_output/mainbunch_000874.mat',
#  '10': '../03_Mini_Simulation_Scan_BLonD/1_H_10/bunch_output/mainbunch_000874.mat',
#  '11': '../03_Mini_Simulation_Scan_BLonD/1_H_11/bunch_output/mainbunch_000874.mat',
#  '12': '../03_Mini_Simulation_Scan_BLonD/1_H_12/bunch_output/mainbunch_000874.mat',
#  '13': '../03_Mini_Simulation_Scan_BLonD/1_H_13/bunch_output/mainbunch_000874.mat',
#  '14': '../03_Mini_Simulation_Scan_BLonD/1_H_14/bunch_output/mainbunch_000874.mat',
#  '15': '../03_Mini_Simulation_Scan_BLonD/1_H_15/bunch_output/mainbunch_000874.mat',
#  '16': '../03_Mini_Simulation_Scan_BLonD/1_H_16/bunch_output/mainbunch_000874.mat',
#  '17': '../03_Mini_Simulation_Scan_BLonD/1_H_17/bunch_output/mainbunch_000874.mat',
#  '18': '../03_Mini_Simulation_Scan_BLonD/1_H_18/bunch_output/mainbunch_000874.mat',
#  '19': '../03_Mini_Simulation_Scan_BLonD/1_H_19/bunch_output/mainbunch_000874.mat',
#  '20': '../03_Mini_Simulation_Scan_BLonD/1_H_20/bunch_output/mainbunch_000874.mat',
#  '21': '../03_Mini_Simulation_Scan_BLonD/1_H_21/bunch_output/mainbunch_000874.mat'}

# %%
#Main function to plot comparison plots with MD data
verbose = True

plotted_names = []

for key, value in sorted(sims_tomo.iteritems()):
    if key not in plotted_names:        
        
        plotted_names.append(key)
        
        this_plot = []
        this_plot.append(value)
        if verbose: print '\nImporting simulation file:', key        

        tune_y = 6.+float(key.split('_')[0])/100
        ctime = 'c172'
        time = float(ctime.split('c')[1])
        label = key
        if verbose: print 'Qy = ', tune_y, ', ctime =', time, '[ms], label = ', label
        
        sim_labels=['Simulation']
# Out:
# Importing simulation file: 07
# Qy =  6.07 , ctime = 172.0 [ms], label =  07
#
# Importing simulation file: 08
# Qy =  6.08 , ctime = 172.0 [ms], label =  08
#
# Importing simulation file: 09
# Qy =  6.09 , ctime = 172.0 [ms], label =  09
#
# Importing simulation file: 10
# Qy =  6.1 , ctime = 172.0 [ms], label =  10
#
# Importing simulation file: 11
# Qy =  6.11 , ctime = 172.0 [ms], label =  11
#
# Importing simulation file: 12
# Qy =  6.12 , ctime = 172.0 [ms], label =  12
#
# Importing simulation file: 13
# Qy =  6.13 , ctime = 172.0 [ms], label =  13
#
# Importing simulation file: 14
# Qy =  6.14 , ctime = 172.0 [ms], label =  14
#
# Importing simulation file: 15
# Qy =  6.15 , ctime = 172.0 [ms], label =  15
#
# Importing simulation file: 16
# Qy =  6.16 , ctime = 172.0 [ms], label =  16
#
# Importing simulation file: 17
# Qy =  6.17 , ctime = 172.0 [ms], label =  17
#
# Importing simulation file: 18
# Qy =  6.18 , ctime = 172.0 [ms], label =  18
#
# Importing simulation file: 19
# Qy =  6.19 , ctime = 172.0 [ms], label =  19
#
# Importing simulation file: 20
# Qy =  6.2 , ctime = 172.0 [ms], label =  20
#
# Importing simulation file: 21
# Qy =  6.21 , ctime = 172.0 [ms], label =  21

# %%
#Main function to plot comparison plots with MD data
verbose = True

plotted_names = []

for key, value in sorted(sims_tomo.iteritems()):
    if key not in plotted_names:        
        
        plotted_names.append(key)
        
        this_plot = []
        this_plot.append(value)
        if verbose: print '\nImporting simulation file:', key        

        tune_x = 6.+float(key.split('_')[0])/100
        ctime = 'c172'
        time = 172.
        label = key
        if verbose: print 'Qx = ', tune_x, ', ctime =', time, '[ms], label = ', label
        
        sim_labels=['Simulation']

        # Find MD data with same tune and ctime    
        for key1, value1 in sorted(sims_tomo.iteritems()):
#             if verbose: print '\tChecking other files:', key1  
            tune_x1 = 6.+float(key1)
            ctime1 = 'c172'
            time1 = 172.
            label1 = key1
#             if verbose: print '\tQy = ', tune_x1, ', ctime =', time1, '[ms], label = ', label1
            if (tune_x1 == tune_x) and (time1 == time):
                if (label1 != label):
                    print '\tMATCH FOUND' 
                    print '\tQx = ', tune_x1, ', ctime =', time1, '[ms]'
                    print '\tlab = ', label, ', lab1 =', label1

                    this_plot.append(value1)
                    plotted_names.append(key1)
                    sim_labels.append(label1)

        # Find rows in dataframe at correct tune and WS time
        md_points = []
        for i in tune_points[tune_x]:
            if df0['PR.BWS.65.H_ROT:ACQ_DELAY'].iloc()[i] == time:
                md_points.append(i)          

        if verbose: print md_points                 

        # Plot data
        main_label = r'$(Q_x, Q_y)$ = (' + str(tune_x) + ', 6.24), t = ' + str(ctime)
        save_name = './H_Plots/WS_tomo/H_Scan_WS_cf_' + str(tune_x) + '_tomo'
        Plot_profiles_cf_sc_models_single(df0, md_points, particles_from_matfile(this_plot[0]), 0, main_label=main_label, save_name=save_name, bins=256, sim_labels=sim_labels, plot_md=True)
# Out:
# Importing simulation file: 07
# Qx =  6.07 , ctime = 172.0 [ms], label =  07
# [187, 209]
#
# 	MAX(y_dat) =  0.06903071278891268
# 	index from y_dat peak not within tolerance of 1 mm.
# 	try manual search
# 	index =  0
# 	index of x_dat =  -23.060552594005312  is  0
# 	Mean of peak point +/- 3 points =  3.03431704566652e-05
# 	WARNING: difference between mean and max_y > 20% =  2273.9999999999786
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  816.8268450971884
# 	 using peak value
#
# Importing simulation file: 08
# Qx =  6.08 , ctime = 172.0 [ms], label =  08
# [8, 31, 54, 76, 99, 142, 163]
#
# 	MAX(y_dat) =  0.07363793911173071
# 	index from y_dat peak not within tolerance of 1 mm.
# 	try manual search
# 	index =  0
# 	index of x_dat =  -19.291786230953143  is  0
# 	Mean of peak point +/- 3 points =  7.421309056359815e-05
# 	WARNING: difference between mean and max_y > 20% =  991.2500000000059
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  1579.6971694941042
# 	 using peak value
#
# Importing simulation file: 09
# Qx =  6.09 , ctime = 172.0 [ms], label =  09
# [186, 208]
#
# 	MAX(y_dat) =  0.07714324067601767
# 	index from y_dat peak not within tolerance of 1 mm.
# 	try manual search
# 	index =  0
# 	index of x_dat =  -17.0381942578038  is  0
# 	Mean of peak point +/- 3 points =  0.0001053581544332402
# 	WARNING: difference between mean and max_y > 20% =  731.1999999999923
# 	 using peak value
#
# Importing simulation file: 10
# Qx =  6.1 , ctime = 172.0 [ms], label =  10
# [7, 30, 53, 75, 98, 121, 141, 162]
#
# 	MAX(y_dat) =  0.08405836784825543
# 	x_dat[index] =  0.1273939541855178
# 	index of x_dat =  0.1273939541855178  is  127
# 	Mean of peak point +/- 3 points =  0.07688862591573017
#
# Importing simulation file: 11
# Qx =  6.11 , ctime = 172.0 [ms], label =  11
# [6, 29, 52, 97, 120, 140, 161, 185, 207]
#
# 	MAX(y_dat) =  0.08783909232218533
# 	x_dat[index] =  0.3175590947715641
# 	index of x_dat =  0.3175590947715641  is  123
# 	Mean of peak point +/- 3 points =  0.07986321087053985
# 	WARNING: difference between mean and max_y > 20% =  1039.9731451738196
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  657.3261887766658
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  5969.066511682008
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  2944.7660799670975
# 	 using peak value
#
# Importing simulation file: 12
# Qx =  6.12 , ctime = 172.0 [ms], label =  12
# [184, 206]
#
# 	MAX(y_dat) =  0.0890265186056404
# 	x_dat[index] =  -0.2745460129191528
# 	index of x_dat =  -0.2745460129191528  is  126
# 	Mean of peak point +/- 3 points =  0.08467559852341003
#
# Importing simulation file: 13
# Qx =  6.13 , ctime = 172.0 [ms], label =  13
# [5, 28, 51, 74, 96, 119, 160]
#
# 	MAX(y_dat) =  0.09283812389811848
# 	index from y_dat peak not within tolerance of 1 mm.
# 	try manual search
# 	index =  0
# 	index of x_dat =  -15.263843697866351  is  0
# 	Mean of peak point +/- 3 points =  6.56563818232804e-05
# 	WARNING: difference between mean and max_y > 20% =  1413.0
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  1078.083546162711
# 	 using peak value
#
# Importing simulation file: 14
# Qx =  6.14 , ctime = 172.0 [ms], label =  14
# [183, 205]
#
# 	MAX(y_dat) =  0.09661281857994657
# 	x_dat[index] =  -0.147917629311479
# 	index of x_dat =  -0.147917629311479  is  127
# 	Mean of peak point +/- 3 points =  0.08753593858466137
#
# Importing simulation file: 15
# Qx =  6.15 , ctime = 172.0 [ms], label =  15
# [4, 27, 50, 73, 95, 118, 159]
#
# 	MAX(y_dat) =  0.098116859769474
# 	x_dat[index] =  -0.638236236181065
# 	index of x_dat =  -0.638236236181065  is  119
# 	Mean of peak point +/- 3 points =  0.08942827800079299
# 	WARNING: difference between mean and max_y > 20% =  1433.0209869571909
# 	 using peak value
#
# Importing simulation file: 16
# Qx =  6.16 , ctime = 172.0 [ms], label =  16
# [182, 204]
#
# 	MAX(y_dat) =  0.09489874578012784
# 	x_dat[index] =  0.8337718015706201
# 	index of x_dat =  0.8337718015706201  is  136
# 	Mean of peak point +/- 3 points =  0.08873445916320263
# 	WARNING: difference between mean and max_y > 20% =  1459.8187434937504
# 	 using peak value
#
# Importing simulation file: 17
# Qx =  6.17 , ctime = 172.0 [ms], label =  17
# [3, 26, 49, 72, 94, 117, 139, 158, 181]
#
# 	MAX(y_dat) =  0.09435151822877366
# 	index from y_dat peak not within tolerance of 1 mm.
# 	try manual search
# 	index =  0
# 	index of x_dat =  -16.602965282338992  is  0
# 	Mean of peak point +/- 3 points =  4.397647085936722e-05
# 	WARNING: difference between mean and max_y > 20% =  2144.5000000000296
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  668.9308603234863
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  717.3139328886487
# 	 using peak value
#
# Importing simulation file: 18
# Qx =  6.18 , ctime = 172.0 [ms], label =  18
# [180]
#
# 	MAX(y_dat) =  0.09423324217777149
# 	x_dat[index] =  0.09744642408608328
# 	index of x_dat =  0.09744642408608328  is  130
# 	Mean of peak point +/- 3 points =  0.09257773445573729
#
# Importing simulation file: 19
# Qx =  6.19 , ctime = 172.0 [ms], label =  19
# [2, 25, 48, 71, 93, 116, 138, 157]
#
# 	MAX(y_dat) =  0.0951457921270562
# 	index from y_dat peak not within tolerance of 1 mm.
# 	try manual search
# 	index =  0
# 	index of x_dat =  -16.7390605912192  is  0
# 	Mean of peak point +/- 3 points =  4.3634850780579514e-05
# 	WARNING: difference between mean and max_y > 20% =  2179.5000000000587
# 	 using peak value
#
# Importing simulation file: 20
# Qx =  6.2 , ctime = 172.0 [ms], label =  20
# [1, 203]
#
# 	MAX(y_dat) =  0.10117938785786554
# 	x_dat[index] =  -0.05333482002486889
# 	index of x_dat =  -0.05333482002486889  is  129
# 	Mean of peak point +/- 3 points =  0.09394038246629392
#
# Importing simulation file: 21
# Qx =  6.21 , ctime = 172.0 [ms], label =  21
# [0, 24, 47, 70, 92, 115, 137, 156]
#
# 	MAX(y_dat) =  0.0954644490754995
# 	x_dat[index] =  -0.9409246813690331
# 	index of x_dat =  -0.9409246813690331  is  128
# 	Mean of peak point +/- 3 points =  0.09053738582835376

# %%
#Main function to plot comparison plots with MD data
verbose = True

plotted_names = []

for key, value in sorted(sims_BLonD.iteritems()):
    if key not in plotted_names:        
        
        plotted_names.append(key)
        
        this_plot = []
        this_plot.append(value)
        if verbose: print '\nImporting simulation file:', key        

        tune_x = 6.+float(key.split('_')[0])/100
        ctime = 'c172'
        time = 172.
        label = key
        if verbose: print 'Qx = ', tune_x, ', ctime =', time, '[ms], label = ', label
        
        sim_labels=['Simulation']

        # Find MD data with same tune and ctime    
        for key1, value1 in sorted(sims_BLonD.iteritems()):
#             if verbose: print '\tChecking other files:', key1  
            tune_x1 = 6.+float(key1)/100
            ctime1 = 'c172'
            time1 = 172.
            label1 = key1
#             if verbose: print '\tQy = ', tune_x1, ', ctime =', time1, '[ms], label = ', label1
            if (tune_x1 == tune_x) and (time1 == time):
                if (label1 != label):
                    print '\tMATCH FOUND' 
                    print '\tQx = ', tune_x1, ', ctime =', time1, '[ms]'
                    print '\tlab = ', label, ', lab1 =', label1

                    this_plot.append(value1)
                    plotted_names.append(key1)
                    sim_labels.append(label1)

        # Find rows in dataframe at correct tune and WS time
        md_points = []
        for i in tune_points[tune_x]:
            if df0['PR.BWS.65.H_ROT:ACQ_DELAY'].iloc()[i] == time:
                md_points.append(i)          

        if verbose: print md_points                 

        # Plot data
        main_label = r'$(Q_x, Q_y)$ = (' + str(tune_x) + ', 6.24), t = ' + str(ctime)
        save_name = './H_Plots/WS_BLonD/H_Scan_WS_cf_' + str(tune_x) + '_BLonD'
        Plot_profiles_cf_sc_models_single(df0, md_points, particles_from_matfile(this_plot[0]), 0, main_label=main_label, save_name=save_name, bins=256, sim_labels=sim_labels, plot_md=True)
# Out:
# Importing simulation file: 07
# Qx =  6.07 , ctime = 172.0 [ms], label =  07
# [187, 209]
#
# 	MAX(y_dat) =  0.06661962605736192
# 	x_dat[index] =  0.2055686783933801
# 	index of x_dat =  0.2055686783933801  is  114
# 	Mean of peak point +/- 3 points =  0.06205142312771394
# 	WARNING: difference between mean and max_y > 20% =  816.8268450971884
# 	 using peak value
#
# Importing simulation file: 08
# Qx =  6.08 , ctime = 172.0 [ms], label =  08
# [8, 31, 54, 76, 99, 142, 163]
#
# 	MAX(y_dat) =  0.06846295878047648
# 	x_dat[index] =  0.8131396352560927
# 	index of x_dat =  0.8131396352560927  is  124
# 	Mean of peak point +/- 3 points =  0.06558165586242923
# 	WARNING: difference between mean and max_y > 20% =  1579.6971694941042
# 	 using peak value
#
# Importing simulation file: 09
# Qx =  6.09 , ctime = 172.0 [ms], label =  09
# [186, 208]
#
# 	MAX(y_dat) =  0.07746160913651365
# 	x_dat[index] =  0.886094958903815
# 	index of x_dat =  0.886094958903815  is  123
# 	Mean of peak point +/- 3 points =  0.07163933132559967
#
# Importing simulation file: 10
# Qx =  6.1 , ctime = 172.0 [ms], label =  10
# [7, 30, 53, 75, 98, 121, 141, 162]
#
# 	MAX(y_dat) =  0.079234442705629
# 	x_dat[index] =  -0.6638813073512075
# 	index of x_dat =  -0.6638813073512075  is  124
# 	Mean of peak point +/- 3 points =  0.07505737429749315
#
# Importing simulation file: 11
# Qx =  6.11 , ctime = 172.0 [ms], label =  11
# [6, 29, 52, 97, 120, 140, 161, 185, 207]
#
# 	MAX(y_dat) =  0.08462375173846387
# 	x_dat[index] =  0.6126611237270119
# 	index of x_dat =  0.6126611237270119  is  129
# 	Mean of peak point +/- 3 points =  0.07679230443211489
# 	WARNING: difference between mean and max_y > 20% =  1039.9731451738196
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  657.3261887766658
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  5969.066511682008
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  2944.7660799670975
# 	 using peak value
#
# Importing simulation file: 12
# Qx =  6.12 , ctime = 172.0 [ms], label =  12
# [184, 206]
#
# 	MAX(y_dat) =  0.09167245167834448
# 	x_dat[index] =  -0.6965909076613936
# 	index of x_dat =  -0.6965909076613936  is  118
# 	Mean of peak point +/- 3 points =  0.08261596924530311
#
# Importing simulation file: 13
# Qx =  6.13 , ctime = 172.0 [ms], label =  13
# [5, 28, 51, 74, 96, 119, 160]
#
# 	MAX(y_dat) =  0.09862297849860235
# 	x_dat[index] =  0.7895258569448185
# 	index of x_dat =  0.7895258569448185  is  134
# 	Mean of peak point +/- 3 points =  0.0876542023550494
# 	WARNING: difference between mean and max_y > 20% =  1078.083546162711
# 	 using peak value
#
# Importing simulation file: 14
# Qx =  6.14 , ctime = 172.0 [ms], label =  14
# [183, 205]
#
# 	MAX(y_dat) =  0.09853850421392504
# 	x_dat[index] =  0.3765712109935997
# 	index of x_dat =  0.3765712109935997  is  141
# 	Mean of peak point +/- 3 points =  0.09017752558066817
#
# Importing simulation file: 15
# Qx =  6.15 , ctime = 172.0 [ms], label =  15
# [4, 27, 50, 73, 95, 118, 159]
#
# 	MAX(y_dat) =  0.09902462400840957
# 	x_dat[index] =  0.4791499701111661
# 	index of x_dat =  0.4791499701111661  is  128
# 	Mean of peak point +/- 3 points =  0.09326208846121162
# 	WARNING: difference between mean and max_y > 20% =  1433.0209869571909
# 	 using peak value
#
# Importing simulation file: 16
# Qx =  6.16 , ctime = 172.0 [ms], label =  16
# [182, 204]
#
# 	MAX(y_dat) =  0.10160116077154228
# 	x_dat[index] =  -0.2594841289934493
# 	index of x_dat =  -0.2594841289934493  is  128
# 	Mean of peak point +/- 3 points =  0.09554257589498959
# 	WARNING: difference between mean and max_y > 20% =  1459.8187434937504
# 	 using peak value
#
# Importing simulation file: 17
# Qx =  6.17 , ctime = 172.0 [ms], label =  17
# [3, 26, 49, 72, 94, 117, 139, 158, 181]
#
# 	MAX(y_dat) =  0.1016281745583969
# 	x_dat[index] =  -0.6675768205938404
# 	index of x_dat =  -0.6675768205938404  is  123
# 	Mean of peak point +/- 3 points =  0.09449476838017046
# 	WARNING: difference between mean and max_y > 20% =  668.9308603234863
# 	 using peak value
# 	WARNING: difference between mean and max_y > 20% =  717.3139328886487
# 	 using peak value
#
# Importing simulation file: 18
# Qx =  6.18 , ctime = 172.0 [ms], label =  18
# [180]
#
# 	MAX(y_dat) =  0.09941733797903006
# 	x_dat[index] =  0.761010349785952
# 	index of x_dat =  0.761010349785952  is  137
# 	Mean of peak point +/- 3 points =  0.09501364791548843
#
# Importing simulation file: 19
# Qx =  6.19 , ctime = 172.0 [ms], label =  19
# [2, 25, 48, 71, 93, 116, 138, 157]
#
# 	MAX(y_dat) =  0.10214352058391513
# 	x_dat[index] =  0.2036136400005013
# 	index of x_dat =  0.2036136400005013  is  128
# 	Mean of peak point +/- 3 points =  0.09713506884382687
#
# Importing simulation file: 20
# Qx =  6.2 , ctime = 172.0 [ms], label =  20
# [1, 203]
#
# 	MAX(y_dat) =  0.10618354974999962
# 	x_dat[index] =  -0.22267478016151188
# 	index of x_dat =  -0.22267478016151188  is  125
# 	Mean of peak point +/- 3 points =  0.09684161723715241
#
# Importing simulation file: 21
# Qx =  6.21 , ctime = 172.0 [ms], label =  21
# [0, 24, 47, 70, 92, 115, 137, 156]
#
# 	MAX(y_dat) =  0.10391960561344812
# 	x_dat[index] =  -0.17018327978799874
# 	index of x_dat =  -0.17018327978799874  is  129
# 	Mean of peak point +/- 3 points =  0.09419314006342172

# %% [markdown]
# # Perform analysis on simulation data

# %%
# Make dataframe with name, tunes, position V, profile V 
data = []
dpp_ = 8.7E-4

# Each row as a list
for key, value in sorted(sims_tomo.iteritems()):
    
    tune_y = float(key.split('_')[0])/100
    time = 172
    if verbose: print 'Qx = ', tune_y, ', time =', time, '[ms]'

    d = particles_from_matfile(value)
    plt.clf()
    x1, bins_1, p1 = plt.hist(d['particles']['x'][0][0][0], bins = 500, density=True, histtype=u'step', lw=1.5, color='k')
          
    qy = 6.24
    qx = tune_y
    pos = np.array(bins_1[:-1]) + (abs(bins_1[0]-bins_1[1])/2)
    prof = x1
    
    new_data = [qx, qy, pos, prof, dpp_]
    
    data.append(new_data)    

# Create dataframe
df_sim_tomo = pd.DataFrame(data, columns = ['Qx', 'Qy', 'PR.BWS.65.H_ROT:PROF_POSITION_IN', 'PR.BWS.65.H_ROT:PROF_DATA_IN', 'dpp'])
# Out:
# Qx =  0.07 , time = 172 [ms]
# Qx =  0.08 , time = 172 [ms]
# Qx =  0.09 , time = 172 [ms]
# Qx =  0.1 , time = 172 [ms]
# Qx =  0.11 , time = 172 [ms]
# Qx =  0.12 , time = 172 [ms]
# Qx =  0.13 , time = 172 [ms]
# Qx =  0.14 , time = 172 [ms]
# Qx =  0.15 , time = 172 [ms]
# Qx =  0.16 , time = 172 [ms]
# Qx =  0.17 , time = 172 [ms]
# Qx =  0.18 , time = 172 [ms]
# Qx =  0.19 , time = 172 [ms]
# Qx =  0.2 , time = 172 [ms]
# Qx =  0.21 , time = 172 [ms]

# %%
# Make dataframe with name, tunes, position V, profile V 
data = []
dpp_ = 8.7E-4

# Each row as a list
for key, value in sorted(sims_BLonD.iteritems()):
    
    tune_y = float(key.split('_')[0])/100
    time = 172
    if verbose: print 'Qx = ', tune_y, ', time =', time, '[ms]'

    d = particles_from_matfile(value)
    plt.clf()
    x1, bins_1, p1 = plt.hist(d['particles']['x'][0][0][0], bins = 500, density=True, histtype=u'step', lw=1.5, color='k')
          
    qy = 6.24
    qx = tune_y
    pos = np.array(bins_1[:-1]) + (abs(bins_1[0]-bins_1[1])/2)
    prof = x1
    
    new_data = [qx, qy, pos, prof, dpp_]
    
    data.append(new_data)    

# Create dataframe
df_sim_BLonD = pd.DataFrame(data, columns = ['Qx', 'Qy', 'PR.BWS.65.H_ROT:PROF_POSITION_IN', 'PR.BWS.65.H_ROT:PROF_DATA_IN', 'dpp'])
# Out:
# Qx =  0.07 , time = 172 [ms]
# Qx =  0.08 , time = 172 [ms]
# Qx =  0.09 , time = 172 [ms]
# Qx =  0.1 , time = 172 [ms]
# Qx =  0.11 , time = 172 [ms]
# Qx =  0.12 , time = 172 [ms]
# Qx =  0.13 , time = 172 [ms]
# Qx =  0.14 , time = 172 [ms]
# Qx =  0.15 , time = 172 [ms]
# Qx =  0.16 , time = 172 [ms]
# Qx =  0.17 , time = 172 [ms]
# Qx =  0.18 , time = 172 [ms]
# Qx =  0.19 , time = 172 [ms]
# Qx =  0.2 , time = 172 [ms]
# Qx =  0.21 , time = 172 [ms]

# %%
# Gaussian and 2nd moment fits
df_sim_tomo_filtered = Multi_filter_sim(df_sim_tomo, with_plot = True, WS = '65.H', smooth=True)
df_sim_BLonD_filtered = Multi_filter_sim(df_sim_BLonD, with_plot = True, WS = '65.H', smooth=True)
# Out:
# Creation of the directory Multi_Filter_Plots failed
#
# Multi_filter row  0
#
# 	initial guess: mu0 -0.8355466797333473
# 	initial guess: offs0 0.0
# 	initial guess: ampl 66.6720053979456
# 	initial guess: slope 0
# 	initial guess: sigma0 34.39215030187022
# 3 parameter fit sigma =  6.019092309847597  +/-  0.023567950225006067
# Removing centre shift of  0.11137470138007743
# Second moment =  6.062228156783036
#
# Multi_filter row  1
#
# 	initial guess: mu0 0.14382993734356544
# 	initial guess: offs0 0.0
# 	initial guess: ampl 69.35735123961298
# 	initial guess: slope 0
# 	initial guess: sigma0 28.123525676014935
# /usr/lib/python2.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in sqrt
# /usr/lib/python2.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in sqrt
# 3 parameter fit sigma =  5.7915270812791055  +/-  0.029335743591940352
# Removing centre shift of  0.04295348155835708
# Second moment =  5.50401844363862
#
# Multi_filter row  2
# 	WARNING: difference between mean and max_y > 20% =  999.9999999999499
# 	 using peak value
#
# 	initial guess: mu0 1.4630518331411724
# 	initial guess: offs0 0.0
# 	initial guess: ampl 82.39336920911825
# 	initial guess: slope 0
# 	initial guess: sigma0 24.762366154632915
# 3 parameter fit sigma =  5.454962741074701  +/-  0.03013050604506604
# Removing centre shift of  0.2125097641703168
# Second moment =  5.068141171040804
#
# Multi_filter row  3
#
# 	initial guess: mu0 0.23590712465851663
# 	initial guess: offs0 0.0
# 	initial guess: ampl 77.17175481291221
# 	initial guess: slope 0
# 	initial guess: sigma0 26.63592924972547
# 3 parameter fit sigma =  5.082156600961062  +/-  0.028630408656319304
# Removing centre shift of  0.12523899478912656
# Second moment =  4.731453592220514
#
# Multi_filter row  4
# 	WARNING: difference between mean and max_y > 20% =  1108.5000000000275
# 	 using peak value
#
# 	initial guess: mu0 2.4380491303107306
# 	initial guess: offs0 0.0
# 	initial guess: ampl 90.49043347718971
# 	initial guess: slope 0
# 	initial guess: sigma0 24.99050106169949
# 3 parameter fit sigma =  4.803575350877433  +/-  0.02536143516940792
# Removing centre shift of  0.06573377874400131
# Second moment =  4.514727199438349
#
# Multi_filter row  5
#
# 	initial guess: mu0 -0.18234876508158374
# 	initial guess: offs0 0.0
# 	initial guess: ampl 85.8940653252848
# 	initial guess: slope 0
# 	initial guess: sigma0 23.385345806782652
# 3 parameter fit sigma =  4.631766066615507  +/-  0.022663908571209077
# Removing centre shift of  0.14138309171554217
# Second moment =  4.404425536915013
#
# Multi_filter row  6
#
# 	initial guess: mu0 -0.7258161793314384
# 	initial guess: offs0 0.0
# 	initial guess: ampl 88.43948827628083
# 	initial guess: slope 0
# 	initial guess: sigma0 23.841556220454066
# 3 parameter fit sigma =  4.482127493623465  +/-  0.021794401778723292
# Removing centre shift of  0.2060384465639169
# Second moment =  4.31400150951883
#
# Multi_filter row  7
#
# 	initial guess: mu0 -0.04534242091095396
# 	initial guess: offs0 0.0
# 	initial guess: ampl 89.0866370113672
# 	initial guess: slope 0
# 	initial guess: sigma0 25.178381405895472
# 3 parameter fit sigma =  4.472280701837037  +/-  0.022079150113963775
# Removing centre shift of  0.1772764126234103
# Second moment =  4.2927844193412525
#
# Multi_filter row  8
#
# 	initial guess: mu0 -0.566899260900311
# 	initial guess: offs0 0.0
# 	initial guess: ampl 88.51976297011423
# 	initial guess: slope 0
# 	initial guess: sigma0 23.601192597269286
# 3 parameter fit sigma =  4.448822174791257  +/-  0.02039219117169514
# Removing centre shift of  0.12942467749363565
# Second moment =  4.285391883978795
#
# Multi_filter row  9
#
# 	initial guess: mu0 0.2361023641745622
# 	initial guess: offs0 0.0
# 	initial guess: ampl 91.99841821710315
# 	initial guess: slope 0
# 	initial guess: sigma0 23.362351274184732
# 3 parameter fit sigma =  4.392329071012633  +/-  0.019096784254706168
# Removing centre shift of  0.12632246721724968
# Second moment =  4.240534159022054
#
# Multi_filter row  10
#
# 	initial guess: mu0 -0.0039590405679149065
# 	initial guess: offs0 0.0
# 	initial guess: ampl 88.89774870985516
# 	initial guess: slope 0
# 	initial guess: sigma0 23.73011882463476
# 3 parameter fit sigma =  4.4197314175874665  +/-  0.022635481573109482
# Removing centre shift of  0.14971011150467115
# Second moment =  4.241355530754801
#
# Multi_filter row  11
#
# 	initial guess: mu0 0.4059439280259241
# 	initial guess: offs0 0.0
# 	initial guess: ampl 92.7053691999319
# 	initial guess: slope 0
# 	initial guess: sigma0 23.95370367261093
# 3 parameter fit sigma =  4.377997495951704  +/-  0.01867295789701838
# Removing centre shift of  0.16260240753800007
# Second moment =  4.228746090848212
#
# Multi_filter row  12
# 	WARNING: difference between mean and max_y > 20% =  1143.4999999999998
# 	 using peak value
#
# 	initial guess: mu0 -1.0828987505485284
# 	initial guess: offs0 0.0
# 	initial guess: ampl 97.53923187182635
# 	initial guess: slope 0
# 	initial guess: sigma0 23.9159034650652
# 3 parameter fit sigma =  4.361796027165902  +/-  0.01935711887562536
# Removing centre shift of  0.16986401750081195
# Second moment =  4.224303496347428
#
# Multi_filter row  13
#
# 	initial guess: mu0 0.04169323068351025
# 	initial guess: offs0 0.0
# 	initial guess: ampl 95.25007094174258
# 	initial guess: slope 0
# 	initial guess: sigma0 21.91214911785549
# 3 parameter fit sigma =  4.328206857460766  +/-  0.021997799092509176
# Removing centre shift of  0.14458819023132408
# Second moment =  4.211273136298311
#
# Multi_filter row  14
#
# 	initial guess: mu0 0.8534052672019617
# 	initial guess: offs0 0.0
# 	initial guess: ampl 91.56223317439483
# 	initial guess: slope 0
# 	initial guess: sigma0 25.098657954283958
# 3 parameter fit sigma =  4.315849689132911  +/-  0.01755782143135613
# Removing centre shift of  0.1461399643187238
# Second moment =  4.204444194388005
# failed rows =  []
# Creation of the directory Multi_Filter_Plots failed
#
# Multi_filter row  0
#
# 	initial guess: mu0 0.2931104486665753
# 	initial guess: offs0 0.0
# 	initial guess: ampl 61.76745256558441
# 	initial guess: slope 0
# 	initial guess: sigma0 37.00751411407723
# 3 parameter fit sigma =  6.411161186705843  +/-  0.0265066430441513
# Removing centre shift of  0.17769264293889134
# Second moment =  6.518969200265665
#
# Multi_filter row  1
#
# 	initial guess: mu0 0.11060032265897482
# 	initial guess: offs0 0.0
# 	initial guess: ampl 66.2799716390949
# 	initial guess: slope 0
# 	initial guess: sigma0 32.596718144426085
# 3 parameter fit sigma =  5.952531708210379  +/-  0.023721139806775236
# Removing centre shift of  -0.059529515420708286
# Second moment =  5.887707605621911
#
# Multi_filter row  2
#
# 	initial guess: mu0 0.9884878744191913
# 	initial guess: offs0 0.0
# 	initial guess: ampl 71.83201346200522
# 	initial guess: slope 0
# 	initial guess: sigma0 28.857136841008113
# 3 parameter fit sigma =  5.592057370277136  +/-  0.02612396757175862
# Removing centre shift of  -0.08857267296020405
# Second moment =  5.377274200570791
#
# Multi_filter row  3
#
# 	initial guess: mu0 -0.5075775639651232
# 	initial guess: offs0 0.0
# 	initial guess: ampl 75.74994522526679
# 	initial guess: slope 0
# 	initial guess: sigma0 24.1088232180979
# 3 parameter fit sigma =  5.344209445707968  +/-  0.030180126568936354
# Removing centre shift of  -0.1519057611667516
# Second moment =  5.001409478398311
#
# Multi_filter row  4
#
# 	initial guess: mu0 -0.6773029555940322
# 	initial guess: offs0 0.0
# 	initial guess: ampl 80.57221865576876
# 	initial guess: slope 0
# 	initial guess: sigma0 23.652476199251154
# 3 parameter fit sigma =  4.979966737185499  +/-  0.025712700192721424
# Removing centre shift of  -0.031103781627532467
# Second moment =  4.654439837318846
#
# Multi_filter row  5
#
# 	initial guess: mu0 0.3832152738872906
# 	initial guess: offs0 0.0
# 	initial guess: ampl 81.44318734749932
# 	initial guess: slope 0
# 	initial guess: sigma0 24.025188131948205
# 3 parameter fit sigma =  4.721688561174162  +/-  0.025143533062028704
# Removing centre shift of  0.015593172041865066
# Second moment =  4.440755365110037
#
# Multi_filter row  6
#
# 	initial guess: mu0 0.10576471905791862
# 	initial guess: offs0 0.0
# 	initial guess: ampl 87.84996620717367
# 	initial guess: slope 0
# 	initial guess: sigma0 21.73943826789425
# 3 parameter fit sigma =  4.531217500710839  +/-  0.0247395803789143
# Removing centre shift of  -0.01854881141232834
# Second moment =  4.285809491330018
#
# Multi_filter row  7
#
# 	initial guess: mu0 0.4489701179681959
# 	initial guess: offs0 0.0
# 	initial guess: ampl 92.37634527988007
# 	initial guess: slope 0
# 	initial guess: sigma0 23.277804126398326
# 3 parameter fit sigma =  4.410788910381256  +/-  0.021275693650563417
# Removing centre shift of  -0.017562875139107866
# Second moment =  4.1902272332063815
#
# Multi_filter row  8
#
# 	initial guess: mu0 0.10775790103472078
# 	initial guess: offs0 0.0
# 	initial guess: ampl 93.04375931248397
# 	initial guess: slope 0
# 	initial guess: sigma0 24.085646633793885
# 3 parameter fit sigma =  4.283391619086659  +/-  0.019114702461274485
# Removing centre shift of  -0.03444565124740763
# Second moment =  4.129485286879908
#
# Multi_filter row  9
#
# 	initial guess: mu0 -0.22592230771005356
# 	initial guess: offs0 0.0
# 	initial guess: ampl 96.2403074828975
# 	initial guess: slope 0
# 	initial guess: sigma0 23.942190979237267
# 3 parameter fit sigma =  4.191412912301793  +/-  0.018509982143547554
# Removing centre shift of  -0.0008860362696949971
# Second moment =  4.066872146298389
# Multi_filter row  10
# 	WARNING: difference between mean and max_y > 20% =  792.3333333333047
# 	 using peak value
#
# 	initial guess: mu0 1.2049039243067963
# 	initial guess: offs0 0.0
# 	initial guess: ampl 106.2794640435988
# 	initial guess: slope 0
# 	initial guess: sigma0 22.821696823869452
# 3 parameter fit sigma =  4.176169027639635  +/-  0.017472630809098274
# Removing centre shift of  -0.007782595401219304
# Second moment =  4.050895570034318
#
# Multi_filter row  11
#
# 	initial guess: mu0 0.7560534679178845
# 	initial guess: offs0 0.0
# 	initial guess: ampl 95.64624606270569
# 	initial guess: slope 0
# 	initial guess: sigma0 22.631165114855158
# 3 parameter fit sigma =  4.145753243171566  +/-  0.01710029059886239
# Removing centre shift of  -0.012535409981216423
# Second moment =  4.031503252405019
#
# Multi_filter row  12
#
# 	initial guess: mu0 0.23398972242122568
# 	initial guess: offs0 0.0
# 	initial guess: ampl 96.83370392166559
# 	initial guess: slope 0
# 	initial guess: sigma0 21.669561981663524
# 3 parameter fit sigma =  4.119638064592593  +/-  0.018006782214311734
# Removing centre shift of  -0.009363123848183177
# Second moment =  4.02347538876166
#
# Multi_filter row  13
#
# 	initial guess: mu0 -0.13667727846280747
# 	initial guess: offs0 0.0
# 	initial guess: ampl 97.3268514328807
# 	initial guess: slope 0
# 	initial guess: sigma0 22.56497884824301
# 3 parameter fit sigma =  4.1215577444660125  +/-  0.017908344386249327
# Removing centre shift of  -0.0265987463345271
# Second moment =  4.023301937183406
#
# Multi_filter row  14
#
# 	initial guess: mu0 -0.1358028567782169
# 	initial guess: offs0 0.0
# 	initial guess: ampl 97.12104179317573
# 	initial guess: slope 0
# 	initial guess: sigma0 22.42391921147504
# 3 parameter fit sigma =  4.131418941747362  +/-  0.018867413384655456
# Removing centre shift of  0.011388120677544538
# Second moment =  4.02850743019713
# failed rows =  []

# %%
df_sim_tomo_emittance = emittance_df(df_sim_tomo_filtered, WS='65.H', verbose=True)
df_sim_BLonD_emittance = emittance_df(df_sim_BLonD_filtered, WS='65.H', verbose=True)
# Out:
# Emittance  0  =  2.759885957371562
# Emittance  1  =  2.4446585145798876
# Emittance  2  =  2.028981038500291
# Emittance  3  =  1.6135496891321126
# Emittance  4  =  1.3331230734100774
# Emittance  5  =  1.1764676659773121
# Emittance  6  =  1.0482778576711693
# Emittance  7  =  1.0525824340025192
# Emittance  8  =  1.0435666904712444
# Emittance  9  =  1.0042800778237257
# Emittance  10  =  1.0400991254053156
# Emittance  11  =  1.0134083488878651
# Emittance  12  =  1.0092397756076263
# Emittance  13  =  0.9895338239354242
# Emittance  14  =  0.9882036004999004
# Emittance  0  =  3.3128966258864203
# Emittance  1  =  2.6539513625503997
# Emittance  2  =  2.193459635302981
# Emittance  3  =  1.9058954212640837
# Emittance  4  =  1.5155882211280636
# Emittance  5  =  1.264542835729687
# Emittance  6  =  1.0942450347599428
# Emittance  7  =  0.9962067790078144
# Emittance  8  =  0.8952936561068645
# Emittance  9  =  0.8280812055005448
# Emittance  10  =  0.8270335152385319
# Emittance  11  =  0.8126168554031539
# Emittance  12  =  0.8015039146278008
# Emittance  13  =  0.8133450724898453
# Emittance  14  =  0.8313255377281104

# %%
df_sim_tomo_emittance_2 = emittance_df_2(df_sim_tomo_emittance, WS='65.H', verbose=True)
df_sim_BLonD_emittance_2 = emittance_df_2(df_sim_BLonD_emittance, WS='65.H', verbose=True)
# Out:
# Emittance from 2nd moment 0  =  2.8190208604719253
# Emittance from 2nd moment 1  =  2.085194085385668
# Emittance from 2nd moment 2  =  1.5869036026134262
# Emittance from 2nd moment 3  =  1.24529930660513
# Emittance from 2nd moment 4  =  1.0485375320263468
# Emittance from 2nd moment 5  =  0.9613503366728446
# Emittance from 2nd moment 6  =  0.8946410855339395
# Emittance from 2nd moment 7  =  0.8902063755177514
# Emittance from 2nd moment 8  =  0.8970529110065011
# Emittance from 2nd moment 9  =  0.8703976193721223
# Emittance from 2nd moment 10  =  0.8828745979859285
# Emittance from 2nd moment 11  =  0.8831136080563566
# Emittance from 2nd moment 12  =  0.8898358918448225
# Emittance from 2nd moment 13  =  0.8887777542846325
# Emittance from 2nd moment 14  =  0.8926221157215242
# Emittance from 2nd moment 0  =  3.471074270325957
# Emittance from 2nd moment 1  =  2.5689952155323796
# Emittance from 2nd moment 2  =  1.9375867786472858
# Emittance from 2nd moment 3  =  1.5264300404791507
# Emittance from 2nd moment 4  =  1.1839853486987442
# Emittance from 2nd moment 5  =  0.9950001889787752
# Emittance from 2nd moment 6  =  0.8694536577427895
# Emittance from 2nd moment 7  =  0.8004164627250167
# Emittance from 2nd moment 8  =  0.7623942287561845
# Emittance from 2nd moment 9  =  0.7230029132984426
# Emittance from 2nd moment 10  =  0.7221479493089465
# Emittance from 2nd moment 11  =  0.7178550366606925
# Emittance from 2nd moment 12  =  0.722301129448224
# Emittance from 2nd moment 13  =  0.7325951977839597
# Emittance from 2nd moment 14  =  0.7467659643131427

# %%
df_sim_tomo_emittance_2.to_pickle('./H_Sim_Dataframes/tomo_Simulation_data_mini.pkl')
df_sim_BLonD_emittance_2.to_pickle('./H_Sim_Dataframes/BLonD_Simulation_data_mini.pkl')

# %% [markdown]
# # Plots

# %%
df0_sim = df_sim_tomo_emittance_2

# Plot averaged data points with error bars
fig=plt.figure(figsize=(8, 4), dpi= 200, facecolor='w', edgecolor='k');
x_data = np.linspace(607, 621, 15);
x_data = x_data/100;

y_data_172 = []
y_error_172 = []

for i in x_data:
    
    upper_lim = i+0.0049999999999 - 6
    lower_lim = i-0.0049999999999 - 6
    
    y_data_172.append( np.mean( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    y_error_172.append( np.std( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    
y_error_172[11] = max(y_error_172)
    
plt.errorbar(x_data, y_data_172, y_error_172, label='Measurement @ 172 ms', linestyle='None', marker='o', capsize=3, color='b')

plt.plot(6.+df0_sim['Qx'], df0_sim['emittance H 2ndMoment'], label='Simulation @ 172 ms', linestyle='None', marker='o', color='r', markersize=5)

plt.xlabel('Qx');
plt.ylabel('Horizontal Emittance [mm mrad]');

plt.title(r'$\epsilon_{x} = \beta\gamma \frac{\mu\prime_x^2 - D_x^2 \left(\frac{\delta p}{p} \right)^2}{\beta_{x}(s)}$')
#plt.title(r'$\epsilon_{x,y} = \beta\gamma \frac{\mu\prime^2}{\beta_{x,y}(s)}$')

# plt.ylim(0.5, 3.5)
plt.ylim(0.5, 4)

plt.legend();
plt.grid();
fig.savefig('H_Plots/H_Emitt_CF_tomo.png');

# %%
df0_sim = df_sim_BLonD_emittance_2

# Plot averaged data points with error bars
fig=plt.figure(figsize=(8, 4), dpi= 200, facecolor='w', edgecolor='k');
x_data = np.linspace(607, 621, 15);
x_data = x_data/100;

y_data_172 = []
y_error_172 = []

for i in x_data:
    
    upper_lim = i+0.0049999999999 - 6
    lower_lim = i-0.0049999999999 - 6
    
    y_data_172.append( np.mean( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    y_error_172.append( np.std( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    
y_error_172[11] = max(y_error_172)
    
plt.errorbar(x_data, y_data_172, y_error_172, label='Measurement @ 172 ms', linestyle='None', marker='o', capsize=3, color='b')

plt.plot(6.+df0_sim['Qx'], df0_sim['emittance H 2ndMoment'], label='Simulation @ 172 ms', linestyle='None', marker='o', color='r', markersize=5)

plt.xlabel('Qx');
plt.ylabel('Horizontal Emittance [mm mrad]');

plt.title(r'$\epsilon_{x} = \beta\gamma \frac{\mu\prime_x^2 - D_x^2 \left(\frac{\delta p}{p} \right)^2}{\beta_{x}(s)}$')
#plt.title(r'$\epsilon_{x,y} = \beta\gamma \frac{\mu\prime^2}{\beta_{x,y}(s)}$')

# plt.ylim(0.5, 3.5)
plt.ylim(0.5, 4)

plt.legend();
plt.grid();
fig.savefig('H_Plots/H_Emitt_CF_BLonD.png');

# %%
df0_sim = df_sim_BLonD_emittance_2

# Plot averaged data points with error bars
fig=plt.figure(figsize=(8, 4), dpi= 200, facecolor='w', edgecolor='k');
x_data = np.linspace(607, 621, 15);
x_data = x_data/100;

y_data_172 = []
y_error_172 = []

for i in x_data:
    
    upper_lim = i+0.0049999999999 - 6
    lower_lim = i-0.0049999999999 - 6
    
    y_data_172.append( np.mean( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    y_error_172.append( np.std( df0['emittance H 2ndMoment'][(df0['PR.BWS.65.H_ROT:ACQ_DELAY']==172)][(df0['Qx']>lower_lim)][(df0['Qx']<upper_lim)] ) )
    
y_error_172[11] = max(y_error_172)
    
plt.errorbar(x_data, y_data_172, y_error_172, label='Measurement @ 172 ms', linestyle='None', marker='o', capsize=3, color='b')
plt.plot(6.+df_sim_BLonD_emittance_2['Qx'], df_sim_BLonD_emittance_2['emittance H 2ndMoment'], label='BLonD Simulation @ 172 ms', linestyle='None', marker='o', color='g', markersize=5)
plt.plot(6.+df_sim_tomo_emittance_2['Qx'], df_sim_tomo_emittance_2['emittance H 2ndMoment'], label='tomo Simulation @ 172 ms', linestyle='None', marker='o', color='m', markersize=5)

plt.xlabel('Qx');
plt.ylabel('Horizontal Emittance [mm mrad]');

plt.title(r'$\epsilon_{x} = \beta\gamma \frac{\mu\prime_x^2 - D_x^2 \left(\frac{\delta p}{p} \right)^2}{\beta_{x}(s)}$')
#plt.title(r'$\epsilon_{x,y} = \beta\gamma \frac{\mu\prime^2}{\beta_{x,y}(s)}$')

# plt.ylim(0.5, 3.5)
plt.ylim(0.5, 4)

plt.legend();
plt.grid();
fig.savefig('H_Plots/H_Emitt_CF_both.png');
